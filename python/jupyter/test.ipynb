# %% [markdown]
# # This is jupyter notebook test
# ## Hailing Fang

# %% [markdown]
# Hi, this is test deminstration of the use of jupyter

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-7, 7, 100)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
ax.grid()
