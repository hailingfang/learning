# %% [markdown]
# # This is a test for jupter notebook code
# ## Benjamin Fang 20240227

# %% [raw]
# Hello, Notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
y = x ** 2

# %%
fig, ax = plt.subplots()
ax.plot(x, y, linestyle="", marker="x")

# %%
fig.savefig("test.svg")
